# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("Environnment ready!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__ }")
# block 2 github practice
# Out:
# Environnment ready!
# Pandas version: 2.2.3
# NumPy version: 2.2.2
